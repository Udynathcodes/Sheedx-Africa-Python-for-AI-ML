# %% [markdown]
# <a href="https://colab.research.google.com/github/Udynathcodes/Sheedx-Africa-Python-for-AI-ML/blob/main/Model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris_dataset = load_iris() # I loaded the data set
X, y = iris_dataset.data, iris_dataset.target # Then separate features from labels (My error here was adding a double (tt) to dataset)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=31) |#split the data into training and test sets (75% training, 25% testing)

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
    data=np.c_[X,y], #Note: np.c_[x,y] is a short hand for concartenation i.e the whole of pd.dataframe has to parameter(data & columns)
    columns=iris_dataset['feature_names'] + ['target'])
df.sample(frac=0.1) # Here I Randomly selects 10% of the rows for viewing or analysis.
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 69                 5.6               2.5                3.9               1.1
# 126                6.2               2.8                4.8               1.8
# 56                 6.3               3.3                4.7               1.6
# 73                 6.1               2.8                4.7               1.2
# 121                5.6               2.8                4.9               2.0
# 128                6.4               2.8                5.6               2.1
# 122                7.7               2.8                6.7               2.0
# 72                 6.3               2.5                4.9               1.5
# 146                6.3               2.5                5.0               1.9
# 135                7.7               3.0                6.1               2.3
# 116                6.5               3.0                5.5               1.8
# ...
