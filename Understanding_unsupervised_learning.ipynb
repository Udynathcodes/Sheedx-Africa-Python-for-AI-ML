# %% [markdown]
# <a href="https://colab.research.google.com/github/Udynathcodes/Sheedx-Africa-Python-for-AI-ML/blob/main/Understanding_unsupervised_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Data
data = {
    'Age': [25, 45, 35, 33, 26, 40, 29, 48],
    'Income': [50000, 80000, 60000, 52000, 48000, 75000, 62000, 85000]
}
df = pd.DataFrame(data)

# K-Means clustering
kmeans = KMeans(n_clusters=2)
df['Cluster'] = kmeans.fit_predict(df)

# Visualization
plt.scatter(df['Age'], df['Income'], c=df['Cluster'], cmap='viridis')
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Customer Clustering')
plt.show()
